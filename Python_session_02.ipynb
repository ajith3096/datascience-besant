# %% [markdown]
# # Strings:

# %%
#Multiline string
x = '''Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''

print(len(x))
# Out:
# 123

# %%
print(x)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
x = "'Apple'"
print(x)
# Out:
# 'Apple'

# %%
#Strings are Arrays. Square brackets can be used to access elements of the string.
a = "Hello, World!"
print(a[1:13])
# Out:
# ello, World!

# %%
#Looping Through a String
for x in "Hello, World!":
    print(x)

print(x)
# Out:
# H
# e
# l
# l
# o
# ,
#
# W
# o
# r
# l
# d
# !
# !

# %%
#String Length
print(len(a)) #lenght calculates the length starting from the number 1
# Out:
# 13

# %%
#Check if and if Not
txt = "The best things in life are free!"
if "free" in txt:
  print("Yes, 'free' is present in the text.")
# Out:
# Yes, 'free' is present in the text.

# %%
#-------------------------------------#

txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %% [markdown]
# # Slicing String

# %%
#Get the characters from position 2 to position 5 (not included):
b = "Hello, World!"
PID = b[2:5]
print(b[2:5])
print(PID)

del PID
# Out:
# llo
# llo

# %%
#Get the characters from the start to position 5 (not included):
b = "Hello, World!"
print(b[:5])
# Out:
# Hello

# %%
#Get the characters from position 2, and all the way to the end:
b = "Hello, World!"
print(b[2:])
# Out:
# llo, World!

# %%
#Negative Indexing
b = "hffghjhgkhljhgjklhgjklhvgklh Error"
print
value = (b[-5:])
if value == "Error":
    print('The process has errored out')
# Out:
# The process has errored out

# %% [markdown]
# # Modify Strings

# %%
#Upper Case
a = "Hello, World!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
#Lower Case
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %%
#Remove Whitespace
a = " Hello, World! "
print(a.strip()) # returns "Hello, World!"
# Out:
# Hello, World!

# %%
#Replace String
a = "Hello, World!"
print(a.replace("H", "J"))
# Out:
# Jello, World!

# %%
#Split String
a = "Hello, World!"
print(a.split("o")) # returns ['Hello', ' World!']
# Out:
# ['Hell', ', W', 'rld!']

# %% [markdown]
# # String Concatenation

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %% [markdown]
# # String Format

# %%
#we cannot combine strings and numbers like this:
age = 36
txt = "My name is John, I am " + age
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-356e59188754> in <module>
#       1 #we cannot combine strings and numbers like this:
#       2 age = 36
# ----> 3 txt = "My name is John, I am " + age
#       4 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#we can combine strings and numbers by using the format() method
age = 36
txt = "My name is John, and I am {}"
print(txt.format(age))
# Out:
# My name is John, and I am 36

# %%
#Format the price to be displayed as a number with two decimals:
price = 49
txt = "The price is {:.2f} dollars"
print(txt.format(price))

# %%
#Named Indexes
myorder = "I have a {carname}, it is a {model}."
print(myorder.format(carname = "Ford", model = "Mustang"))

# %%
#You can use index numbers (a number inside the curly brackets {0}) to be sure the values are placed in the correct placeholders:
quantity = 3
itemno = 567
price = 49
myorder = "I want {0} pieces of item number {1} for {2:.2f} dollars."
print(myorder.format(quantity, itemno, price))

# %% [markdown]
# # Escape Character

# %% [markdown]
# To insert characters that are illegal in a string, use an escape character.
#
# An escape character is a backslash \ followed by the character you want to insert.
#
# An example of an illegal character is a double quote inside a string that is surrounded by double quotes:

# %%
txt = "We are the so-called "+" from the north."
print(txt)
# Out:
# We are the so-called  from the north.

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %% [markdown]
# Other escape characters used in Python:
# ![image.png](attachment:image.png)
#
# You can find these here :https://www.w3schools.com/python/python_strings_escape.asp

# %% [markdown]
# # All String Methods
# ![image.png](attachment:image.png)
#
# You can find these methods here https://www.w3schools.com/python/python_strings_methods.asp
